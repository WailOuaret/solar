# %% [markdown]
# # 06 Error Analysis
#
# Use this notebook to inspect worst predictions, false positives, false negatives, glare confusion, and weather-related failures.

# %%
import pandas as pd

rgb = pd.read_csv('../outputs/predictions/deepsolareye_predictions.csv')
rgb.sort_values('pred_power_loss_pct', ascending=False).head()
