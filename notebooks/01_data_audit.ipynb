# %% [markdown]
# # 01 Data Audit
#
# Use this notebook to inspect sample counts, image sizes, missing metadata, class imbalance, duplicates, and leakage risk before training.

# %%
import pandas as pd

metadata = pd.read_csv('../data/processed/unified_metadata/metadata_master.csv')
metadata.groupby('dataset_name').size()
