# %% [markdown]
# # 03 RGB Baseline
#
# Track the first DeepSolarEye baseline for power-loss regression and severity classification.

# %%
import pandas as pd

history = pd.read_csv('../outputs/models/deepsolareye/training_history.csv')
history.tail()
