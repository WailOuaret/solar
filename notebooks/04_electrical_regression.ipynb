# %% [markdown]
# # 04 Electrical Regression
#
# Compare image-only and image-plus-weather experiments on the Villegas branch.

# %%
import pandas as pd

history = pd.read_csv('../outputs/models/villegas/training_history.csv')
history.tail()
