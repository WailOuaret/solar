# %% [markdown]
# # 05 Thermal Hotspot
#
# Inspect the TRSAI hotspot branch results and failure cases.

# %%
import pandas as pd

preds = pd.read_csv('../outputs/predictions/trsai_predictions.csv')
preds.head()
