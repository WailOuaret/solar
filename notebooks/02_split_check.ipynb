# %% [markdown]
# # 02 Split Check
#
# Use this notebook to verify leakage-safe splits by session, date block, or panel identifier.

# %%
import json
from pathlib import Path

for path in Path('../data/splits').glob('*_split.json'):
    print(path.name)
    print(json.loads(path.read_text()))
