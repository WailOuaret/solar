# %% [markdown]
# # 02 Dataset Alignment
#
# Inspect how the three datasets map into the unified metadata schema.

# %%
import pandas as pd

metadata = pd.read_csv('../data/processed/unified_metadata/metadata_master.csv')
metadata[['dataset_name', 'modality', 'power_loss_pct', 'pmpp', 'isc', 'ff', 'hotspot_label']].head()
